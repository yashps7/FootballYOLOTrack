# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/74.9 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/74.9 kB ? eta -:--:--
#    --------------------- ------------------ 41.0/74.9 kB 393.8 kB/s eta 0:00:01
#    -------------------------------- ------- 61.4/74.9 kB 409.6 kB/s eta 0:00:01
#    ---------------------------------------- 74.9/74.9 kB 375.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/158.3 kB 1.3 MB/s eta 0:00:01
#    --------------- ----------------------- 61.4/158.3 kB 812.7 kB/s eta 0:00:01
#    --------------------------- ---------- 112.6/158.3 kB 939.4 kB/s eta 0:00:01
#    ------------------------------------ - 153.6/158.3 kB 919.0 kB/s eta 0:00:01
#    -------------------------------------- 158.3/158.3 kB 861.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
# ...

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3TvFP0MLl5hqIlCZCo3E")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:04<00:00, 288.43it/s]

# %%
dataset.location
# Out:
# 'c:\\ACADEMICS\\PlacementPrep\\Projects\\Football\\training\\football-players-detection-1'

# %%
# We need to move train, test and valid datasets from one folder to folder as requirement of training code in ultralytics. 
#Hence we use shutil for that.

import shutil

#   (from location, new location)
shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Need strong GPU or colab
